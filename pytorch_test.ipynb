# %%
import torch
import cv2
import numpy as np

# %%
if torch.cuda.is_available():
    # Get the number of available GPU devices
    num_devices = torch.cuda.device_count()

    print(f"CUDA is available with {num_devices} device(s).")
    for i in range(num_devices):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available with 1 device(s).
# GPU 0: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
torch.cuda.is_available()
torch.device("cuda")
# Out:
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"PyTorch is using: {device}")
# Out:
# PyTorch is using: cuda

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
model.cuda()
# Out:
# Using cache found in C:\Users\cbarr/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-10-20 Python-3.10.10 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
video_path = 'USMNT vs. Ghana _ Highlights_ October 17, 2023.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
cap = cv2.VideoCapture(video_path)
width = int(cap.get(3))
height = int(cap.get(4))
out = cv2.VideoWriter("output.mp4", fourcc, 24.0, (width, height))

while cap.isOpened():
    ret,frame =  cap.read()
    print("tratando frame")
    if not ret:break
    
    detection = model(frame)
    frame_with_detection= detection.render()[0]
    out.write(frame_with_detection)
    cv2.imshow("video",np.squeeze(frame_with_detection))
    if cv2.waitKey(1) > 0: break

# %%
img = cv2.imread("151_jpg.rf.c4c44e9a3e29493053f107c6ec46f7c2.jpg")

results = model(img)

# Results
results.print()
results.save()  # or .show()

pred = results.xyxy[0]  # img1 predictions (tensor)
for det in pred:
        x_min, y_min, x_max, y_max, conf, class_id = det
        x_min, y_min, x_max, y_max = map(int, [x_min, y_min, x_max, y_max])

        # Dibujar rectángulo en el marco
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

    # Mostrar el marco con los rectángulos dibujados
cv2.imshow('Manual Object Detection', img)
cv2.waitKey(1) 
# results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# image 1/1: 640x640 27 persons, 1 tennis racket
# Speed: 6.2ms pre-process, 117.8ms inference, 4.3ms NMS per image at shape (1, 3, 640, 640)
# Saved 1 image to runs\detect\exp3
# -1
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np

# Cargar la imagen y la máscara
imagen = cv2.imread('10748_jpg.rf.c86bc9a4116f0102ad8ccde07a050dec.jpg')
mascara = np.zeros(imagen.shape[:2], dtype=np.uint8)
mascara[50:100, 50:100] = 255  # Ajusta las coordenadas de la máscara según tus necesidades

# Coordenadas de la máscara
min_y, max_y = 50, 100  # Ajusta según las coordenadas de la máscara
min_x, max_x = 50, 100  # Ajusta según las coordenadas de la máscara

# Seleccionar la región de interés de la imagen
nueva_imagen = imagen[min_y:max_y, min_x:max_x]

# Mostrar la nueva imagen
cv2.imshow('Nueva Imagen', nueva_imagen)
cv2.waitKey(0)
cv2.destroyAllWindows()
